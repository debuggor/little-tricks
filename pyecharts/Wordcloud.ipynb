# %%
str = '之前做PPT的时候尝试了很多做词云图的工具，网上搜一搜这样的工具的确还是挺多的，不过做出来总是不满意，现有的中文词云工具都不太好用，要么太丑不能调格式，要么不能自定义关键词'
name = list(str)
name
# Out:
# ['之',
#  '前',
#  '做',
#  'P',
#  'P',
#  'T',
#  '的',
#  '时',
#  '候',
#  '尝',
#  '试',
#  '了',
#  '很',
#  '多',
#  '做',
#  '词',
#  '云',
#  '图',
#  '的',
#  '工',
#  '具',
#  '，',
#  '网',
#  '上',
#  '搜',
#  '一',
#  '搜',
#  '这',
#  '样',
#  '的',
#  '工',
#  '具',
#  '的',
#  '确',
#  '还',
#  '是',
#  '挺',
#  '多',
#  '的',
#  '，',
#  '不',
#  '过',
#  '做',
#  '出',
#  '来',
#  '总',
#  '是',
#  '不',
#  '满',
#  '意',
#  '，',
#  '现',
#  '有',
#  '的',
#  '中',
#  '文',
#  '词',
#  '云',
#  '工',
#  '具',
#  '都',
#  '不',
#  '太',
#  '好',
#  '用',
#  '，',
#  '要',
#  '么',
#  '太',
#  '丑',
#  '不',
#  '能',
#  '调',
#  '格',
#  '式',
#  '，',
#  '要',
#  '么',
#  '不',
#  '能',
#  '自',
#  '定',
#  '义',
#  '关',
#  '键',
#  '词']

# %%
len(name)
# Out:
# 86

# %%
import numpy as np
value = np.linspace(1,86,86)

# %%
from pyecharts import WordCloud
wordcloud = WordCloud(width=800, height=600)

wordcloud.add("", name, value, word_size_range=[1,50], shape='star')
wordcloud
# Out:
# <script>
#     require.config({
#          paths:{
#            'echarts': '/nbextensions/echarts/echarts.min', 'wordcloud': '/nbextensions/echarts/echarts-wordcloud.min'
#          }
#     });
# </script>
# <div id="0acdede1bf8f48029ce8e677e552ed48" style="width:800px; height:600px;"></div>
#
# <script>
#     require([ 'echarts', 'wordcloud' ],function(ec){
# 	         var myChart = ec.init(document.getElementById('0acdede1bf8f48029ce8e677e552ed48'));
#          var option =  {
#     "title": [
#         {
#             "text": "",
#             "subtext": "",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "color": "#000",
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "color": "#aaa",
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
# ...
